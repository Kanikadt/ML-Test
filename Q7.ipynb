# %%
data = {
    2022: {
        'Branch 1': {
            'Roll Number': 1,
            'Name': 'A',
            'Marks': {
                'Maths': 90,
                'English': 70,
                
            }
        },
        'Branch 2': {
            'Roll Number': 2,
            'Name': 'B',
            'Marks': {
                'Maths': 90,
                'English': 80,
                
            }
        }
    },
    
    2023: {
        'Branch 1': {
            'Roll Number': 3,
            'Name': 'C',
            'Marks': {
                'Maths': 100,
                'English': 70,
                
            }
        },
        'Branch 2': {
            'Roll Number': 4,
            'Name': 'D',
            'Marks': {
                'Maths': 100,
                'English': 80,
                
            }
        }
    },
    
    2024: {
        'Branch 1': {
            'Roll Number': 5,
            'Name': 'E',
            'Marks': {
                'Maths': 100,
                'English': 70,
                
            }
        },
        'Branch 2': {
            'Roll Number': 6,
            'Name': 'F',
            'Marks': {
                'Maths': 100,
                'English': 100,
               
            }
        }
    },
    
    2025: {
        'Branch 1': {
            'Roll Number': 7,
            'Name': 'G',
            'Marks': {
                'Maths': 40,
                'English': 70,
                
            }
        },
        'Branch 2': {
            'Roll Number': 8,
            'Name': 'H',
            'Marks': {
                'Maths': 90,
                'English': 80,
                
            }
        }
    },
}

# %%
data
# Out:
# {2022: {'Branch 1': {'Roll Number': 1,
#    'Name': 'A',
#    'Marks': {'Maths': 90, 'English': 70}},
#   'Branch 2': {'Roll Number': 2,
#    'Name': 'B',
#    'Marks': {'Maths': 90, 'English': 80}}},
#  2023: {'Branch 1': {'Roll Number': 3,
#    'Name': 'C',
#    'Marks': {'Maths': 100, 'English': 70}},
#   'Branch 2': {'Roll Number': 4,
#    'Name': 'D',
#    'Marks': {'Maths': 100, 'English': 80}}},
#  2024: {'Branch 1': {'Roll Number': 5,
#    'Name': 'E',
#    'Marks': {'Maths': 100, 'English': 70}},
#   'Branch 2': {'Roll Number': 6,
#    'Name': 'F',
#    'Marks': {'Maths': 100, 'English': 100}}},
#  2025: {'Branch 1': {'Roll Number': 7,
#    'Name': 'G',
#    'Marks': {'Maths': 40, 'English': 70}},
#   'Branch 2': {'Roll Number': 8,
#    'Name': 'H',
#    'Marks': {'Maths': 90, 'English': 80}}}}
